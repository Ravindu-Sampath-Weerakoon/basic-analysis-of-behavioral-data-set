# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravindu-Sampath-Weerakoon/basic-analysis-of-behavioral-data-set/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
print("world")

# %% [markdown]
# This is come form colab
